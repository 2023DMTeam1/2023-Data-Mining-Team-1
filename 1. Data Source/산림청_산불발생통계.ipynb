# %%
! pip install xmltodict
import requests, xmltodict, json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
url = 'http://apis.data.go.kr/1400000/forestStusService/getfirestatsservice?searchStDt=20110101&searchEdDt=20111231&ServiceKey=KRywiil%2F5%2BbBBrUF40TtfdDC%2BZaSULjvGL7SaSDxAKfV%2F%2BSedTZfzk1GpkG71vmRaGcJqa5o1KZ%2FWEo1WdoDIQ%3D%3D&numOfRows=554'

res = requests.get(url)

dict_res = xmltodict.parse(res.content)
json_string = json.dumps(dict_res['response']['body']['items'], ensure_ascii=False)

jsonObj = json.loads(json_string)
df_2011 = pd.DataFrame(jsonObj['item'])

# %%
url = 'http://apis.data.go.kr/1400000/forestStusService/getfirestatsservice?searchStDt=20120101&searchEdDt=20121231&ServiceKey=KRywiil%2F5%2BbBBrUF40TtfdDC%2BZaSULjvGL7SaSDxAKfV%2F%2BSedTZfzk1GpkG71vmRaGcJqa5o1KZ%2FWEo1WdoDIQ%3D%3D&numOfRows=394'

res = requests.get(url)

dict_res = xmltodict.parse(res.content)
json_string = json.dumps(dict_res['response']['body']['items'], ensure_ascii=False)

jsonObj = json.loads(json_string)
df_2012 = pd.DataFrame(jsonObj['item'])

# %%
url = 'http://apis.data.go.kr/1400000/forestStusService/getfirestatsservice?searchStDt=20130101&searchEdDt=20131231&ServiceKey=KRywiil%2F5%2BbBBrUF40TtfdDC%2BZaSULjvGL7SaSDxAKfV%2F%2BSedTZfzk1GpkG71vmRaGcJqa5o1KZ%2FWEo1WdoDIQ%3D%3D&numOfRows=592'

res = requests.get(url)

dict_res = xmltodict.parse(res.content)
json_string = json.dumps(dict_res['response']['body']['items'], ensure_ascii=False)

jsonObj = json.loads(json_string)
df_2013 = pd.DataFrame(jsonObj['item'])

# %%
url = 'http://apis.data.go.kr/1400000/forestStusService/getfirestatsservice?searchStDt=20140101&searchEdDt=20141231&ServiceKey=KRywiil%2F5%2BbBBrUF40TtfdDC%2BZaSULjvGL7SaSDxAKfV%2F%2BSedTZfzk1GpkG71vmRaGcJqa5o1KZ%2FWEo1WdoDIQ%3D%3D&numOfRows=984'

res = requests.get(url)

dict_res = xmltodict.parse(res.content)
json_string = json.dumps(dict_res['response']['body']['items'], ensure_ascii=False)

jsonObj = json.loads(json_string)
df_2014 = pd.DataFrame(jsonObj['item'])

# %%
url = 'http://apis.data.go.kr/1400000/forestStusService/getfirestatsservice?searchStDt=20150101&searchEdDt=20151231&ServiceKey=KRywiil%2F5%2BbBBrUF40TtfdDC%2BZaSULjvGL7SaSDxAKfV%2F%2BSedTZfzk1GpkG71vmRaGcJqa5o1KZ%2FWEo1WdoDIQ%3D%3D&numOfRows=1246'

res = requests.get(url)

dict_res = xmltodict.parse(res.content)
json_string = json.dumps(dict_res['response']['body']['items'], ensure_ascii=False)

jsonObj = json.loads(json_string)
df_2015 = pd.DataFrame(jsonObj['item'])

# %%
url = 'http://apis.data.go.kr/1400000/forestStusService/getfirestatsservice?searchStDt=20160101&searchEdDt=20161231&ServiceKey=KRywiil%2F5%2BbBBrUF40TtfdDC%2BZaSULjvGL7SaSDxAKfV%2F%2BSedTZfzk1GpkG71vmRaGcJqa5o1KZ%2FWEo1WdoDIQ%3D%3D&numOfRows=782'

res = requests.get(url)

dict_res = xmltodict.parse(res.content)
json_string = json.dumps(dict_res['response']['body']['items'], ensure_ascii=False)

jsonObj = json.loads(json_string)
df_2016 = pd.DataFrame(jsonObj['item'])

# %%
url = 'http://apis.data.go.kr/1400000/forestStusService/getfirestatsservice?searchStDt=20170101&searchEdDt=20171231&ServiceKey=KRywiil%2F5%2BbBBrUF40TtfdDC%2BZaSULjvGL7SaSDxAKfV%2F%2BSedTZfzk1GpkG71vmRaGcJqa5o1KZ%2FWEo1WdoDIQ%3D%3D&numOfRows=1384'

res = requests.get(url)

dict_res = xmltodict.parse(res.content)
json_string = json.dumps(dict_res['response']['body']['items'], ensure_ascii=False)

jsonObj = json.loads(json_string)
df_2017 = pd.DataFrame(jsonObj['item'])

# %%
url = 'http://apis.data.go.kr/1400000/forestStusService/getfirestatsservice?searchStDt=20180101&searchEdDt=20181231&ServiceKey=KRywiil%2F5%2BbBBrUF40TtfdDC%2BZaSULjvGL7SaSDxAKfV%2F%2BSedTZfzk1GpkG71vmRaGcJqa5o1KZ%2FWEo1WdoDIQ%3D%3D&numOfRows=992'

res = requests.get(url)

dict_res = xmltodict.parse(res.content)
json_string = json.dumps(dict_res['response']['body']['items'], ensure_ascii=False)

jsonObj = json.loads(json_string)
df_2018 = pd.DataFrame(jsonObj['item'])

# %%
url = 'http://apis.data.go.kr/1400000/forestStusService/getfirestatsservice?searchStDt=20190101&searchEdDt=20191231&ServiceKey=KRywiil%2F5%2BbBBrUF40TtfdDC%2BZaSULjvGL7SaSDxAKfV%2F%2BSedTZfzk1GpkG71vmRaGcJqa5o1KZ%2FWEo1WdoDIQ%3D%3D&numOfRows=1306'

res = requests.get(url)

dict_res = xmltodict.parse(res.content)
json_string = json.dumps(dict_res['response']['body']['items'], ensure_ascii=False)

jsonObj = json.loads(json_string)
df_2019 = pd.DataFrame(jsonObj['item'])

# %%
url = 'http://apis.data.go.kr/1400000/forestStusService/getfirestatsservice?searchStDt=20200101&searchEdDt=20201231&ServiceKey=KRywiil%2F5%2BbBBrUF40TtfdDC%2BZaSULjvGL7SaSDxAKfV%2F%2BSedTZfzk1GpkG71vmRaGcJqa5o1KZ%2FWEo1WdoDIQ%3D%3D&numOfRows=1240'

res = requests.get(url)

dict_res = xmltodict.parse(res.content)
json_string = json.dumps(dict_res['response']['body']['items'], ensure_ascii=False)

jsonObj = json.loads(json_string)
df_2020 = pd.DataFrame(jsonObj['item'])

# %%
url = 'http://apis.data.go.kr/1400000/forestStusService/getfirestatsservice?searchStDt=20210101&searchEdDt=20211231&ServiceKey=KRywiil%2F5%2BbBBrUF40TtfdDC%2BZaSULjvGL7SaSDxAKfV%2F%2BSedTZfzk1GpkG71vmRaGcJqa5o1KZ%2FWEo1WdoDIQ%3D%3D&numOfRows=698'

res = requests.get(url)

dict_res = xmltodict.parse(res.content)
json_string = json.dumps(dict_res['response']['body']['items'], ensure_ascii=False)

jsonObj = json.loads(json_string)
df_2021 = pd.DataFrame(jsonObj['item'])

# %%
new_df = pd.concat([df_2011, df_2012, df_2013, df_2014, df_2015, df_2016, df_2017, df_2018, df_2019, df_2020, df_2021], ignore_index = True)

# %%
new_df
# Out:
#       damagearea endday endmonth   endtime endyear firecause  locbunji  \
# 0            0.1     28       12  08:30:00    2011     입산자실화    산202-2
# 1            0.5     24       12  16:30:00    2011     쓰레기소각     산14-1
# 2           0.01     22       12  18:20:00    2011     입산자실화       산52
# 3            0.2     09       12  15:00:00    2011        기타       산27
# 4            0.3     29       11  22:30:00    2011     담뱃불실화      산4-1
# ...          ...    ...      ...       ...     ...       ...       ...
# 10167        0.4     01       04  18:50:00    2021     쓰레기소각      산102
# 10168       0.01     01       04  13:30:00    2021     입산자실화      산251
# 10169        0.1     01       04  15:30:00    2021     담뱃불실화     산33-3
# 10170       10.7     01       04  12:54:00    2021        기타  산146외1필지
# 10171       0.01     01       04  15:30:00    2021        기타     663-9
#
#       locdong locgungu locmenu locsi startday startdayofweek startmonth  \
# ...

# %%
new_df.columns = ['피해면적합계','진화종료 일','진화종료 월','진화종료 일시','진화종료 연도','발생원인','발생장소_지번','발생장소_동리','발생장소_시군구','발생장소_읍면','발생장소_시도','발생일','발생요일','발생월','발생시간','발생연도']

# %%
new_df
# Out:
#       피해면적합계 진화종료 일 진화종료 월   진화종료 일시 진화종료 연도   발생원인   발생장소_지번 발생장소_동리  \
# 0        0.1     28     12  08:30:00    2011  입산자실화    산202-2     장전평
# 1        0.5     24     12  16:30:00    2011  쓰레기소각     산14-1      무계
# 2       0.01     22     12  18:20:00    2011  입산자실화       산52       원
# 3        0.2     09     12  15:00:00    2011     기타       산27      용수
# 4        0.3     29     11  22:30:00    2011  담뱃불실화      산4-1      거포
# ...      ...    ...    ...       ...     ...    ...       ...     ...
# 10167    0.4     01     04  18:50:00    2021  쓰레기소각      산102      쌍지
# 10168   0.01     01     04  13:30:00    2021  입산자실화      산251      양잠
# 10169    0.1     01     04  15:30:00    2021  담뱃불실화     산33-3      어천
# 10170   10.7     01     04  12:54:00    2021     기타  산146외1필지      운치
# 10171   0.01     01     04  15:30:00    2021     기타     663-9      화전
#
#       발생장소_시군구 발생장소_읍면 발생장소_시도 발생일 발생요일 발생월      발생시간  발생연도
# 0           홍천      홍천      강원  28  수요일  12  03:20:00  2011
# ...

# %%
new_df.to_csv('피해면적.csv',encoding='euc-kr')
