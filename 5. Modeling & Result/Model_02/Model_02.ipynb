# %%
import pandas as pd
df = pd.read_csv("final.csv",encoding='UTF8')

# %%
df
# Out:
#                   화재발생일시  화재발생_연  화재발생_월  화재발생_일  주말여부 화재발생시간대 시군구명  읍면동명  \
# 0    2011-01-22 23:35:00    2011       1      22     1   21~24  강릉시   죽헌동
# 1    2011-01-31 18:13:00    2011       1      31     0   18~21  양양군   현남면
# 2    2011-02-11 17:50:00    2011       2      11     0   15~18  홍천군   내촌면
# 3    2011-02-12 06:18:00    2011       2      12     1     3~6  원주시   귀래면
# 4    2011-02-26 16:42:00    2011       2      26     1   15~18  원주시   태장동
# ..                   ...     ...     ...     ...   ...     ...  ...   ...
# 534  2021-05-09 13:43:01    2021       5       9     1   12~15  철원군   철원읍
# 535  2021-05-09 17:44:49    2021       5       9     1   15~18  철원군   철원읍
# 536  2021-05-13 15:37:05    2021       5      13     0   15~18  태백시  하사미동
# 537  2021-06-07 15:11:39    2021       6       7     0   15~18  강릉시  주문진읍
# 538  2021-06-08 14:52:46    2021       6       8     0   12~15  홍천군   내촌면
#
#     발화지점    날씨  ...  출동소요시간  현장소방서거리 현장안전센터거리 현장소방지역대거리 전체인력수합계  화재진압시간 동원장비수  \
# ...

# %%
df.shape
# Out:
# (539, 27)

# %%
data = df.drop(['화재발생일시','화재발생_연','화재발생_일','읍면동명', '특보내용', '소방지역대명','전체인력수합계','화재진압시간','동원장비수','인명피해수','재산피해금액'],axis=1)

# %%
#분석에 필요한 변수만 남김
data
# Out:
#      화재발생_월  주말여부 화재발생시간대 시군구명 발화지점    날씨  온도  습도       발화원인종합   소방서명  \
# 0         1     1   21~24  강릉시  산정상    맑음  -1  30    방화 및 방화의심  강릉소방서
# 1         1     0   18~21  양양군  산아래    맑음   1  10      인간의 부주의  양양소방서
# 2         2     0   15~18  홍천군  산중턱  구름많음  -2  29      인간의 부주의  홍천소방서
# 3         2     1     3~6  원주시  산중턱  구름많음  -6  44      인간의 부주의  원주소방서
# 4         2     1   15~18  원주시  산정상    맑음  14  23      인간의 부주의  원주소방서
# ..      ...   ...     ...  ...  ...   ...  ..  ..          ...    ...
# 534       5     1   12~15  철원군  산중턱    맑음  19  26      인간의 부주의  철원소방서
# 535       5     1   15~18  철원군  산정상    맑음  18  22      인간의 부주의  철원소방서
# 536       5     0   15~18  태백시  산중턱    맑음  23  43  기계/전기/화학 요인  태백소방서
# 537       6     0   15~18  강릉시  산중턱    맑음  25  62      인간의 부주의  강릉소방서
# 538       6     0   12~15  홍천군  산정상    맑음  18  78       자연적 요인  홍천소방서
#
#            서센터명  출동소요시간  현장소방서거리  현장안전센터거리  현장소방지역대거리   피해면적
# 0     경포119안전센터    1700        9         9        0.0   0.30
# ...

# %%
from matplotlib import font_manager, rc
font_path = "c:/windows/Fonts/malgun.ttf" #한글 폰트 경로
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family = font_name)

# %%
import matplotlib.pyplot as plt

# 시각화 필요한 열만 선택
selected_columns = ['현장소방서거리', '현장안전센터거리', '현장소방지역대거리', '출동소요시간']
selected_data = data[selected_columns]

# 시각화
plt.figure(figsize=(12, 8))
plt.scatter(selected_data['현장소방서거리'], selected_data['출동소요시간'], label='현장소방서거리')
plt.scatter(selected_data['현장안전센터거리'], selected_data['출동소요시간'], label='현장안전센터거리')
plt.scatter(selected_data['현장소방지역대거리'], selected_data['출동소요시간'], label='현장소방지역대거리')
plt.xlabel('거리')
plt.ylabel('출동소요시간')
plt.legend()
plt.show()

# 상관계수 계산
correlation = selected_data.corr()
print(correlation)
# Out:
#             현장소방서거리  현장안전센터거리  현장소방지역대거리    출동소요시간
# 현장소방서거리    1.000000  0.475144   0.259697  0.245447
# 현장안전센터거리   0.475144  1.000000   0.290189  0.340478
# 현장소방지역대거리  0.259697  0.290189   1.000000  0.167438
# 출동소요시간     0.245447  0.340478   0.167438  1.000000

# %%
import numpy as np

# 현장소방지역대거리 전체 인스턴스 개수
total_instances = len(data["현장소방지역대거리"])
print("전체 인스턴스 개수:", total_instances)

# 현장소방지역대거리 null 값 개수, 0 값 개수
null_values = data["현장소방지역대거리"].isnull().sum()
zero_values = len(data[data["현장소방지역대거리"] == 0])
print("null 값 개수:", null_values)
print("0 값 개수:", zero_values)
# Out:
# 전체 인스턴스 개수: 539
# null 값 개수: 1
# 0 값 개수: 318

# %%
data = data.drop(['현장소방지역대거리'],axis=1)

# %%
# 시각화 필요한 열만 선택
selected_columns = ['현장소방서거리', '현장안전센터거리', '출동소요시간']
selected_data = data[selected_columns]

# 시각화
plt.figure(figsize=(12, 8))
plt.scatter(selected_data['현장소방서거리'], selected_data['출동소요시간'], label='현장소방서거리')
plt.scatter(selected_data['현장안전센터거리'], selected_data['출동소요시간'], label='현장안전센터거리')
plt.xlabel('거리')
plt.ylabel('출동소요시간')
plt.legend()
plt.show()

# 상관계수 계산
correlation = selected_data.corr()
print(correlation)
# Out:
#            현장소방서거리  현장안전센터거리    출동소요시간
# 현장소방서거리   1.000000  0.475144  0.245447
# 현장안전센터거리  0.475144  1.000000  0.340478
# 출동소요시간    0.245447  0.340478  1.000000

# %%
#Feature 와 target 나누기
features = data[data.columns[:-1]]
target = data[data.columns[-1]]

# %%
# 문자열 데이터를 숫자형 데이터로 변환
features = pd.get_dummies(data = features, columns = ['화재발생시간대'], prefix = '화재발생시간대')
features = pd.get_dummies(data = features, columns = ['시군구명'], prefix = '시군구명')
features = pd.get_dummies(data = features, columns = ['발화지점'], prefix = '발화지점')
features = pd.get_dummies(data = features, columns = ['날씨'], prefix = '날씨')
features = pd.get_dummies(data = features, columns = ['발화원인종합'], prefix = '발화원인종합')

features = pd.get_dummies(data = features, columns = ['소방서명'], prefix = '소방서명')
features = pd.get_dummies(data = features, columns = ['서센터명'], prefix = '서센터명')

# %%
#Data split: Train,test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    features, target, test_size=0.2,random_state = 22)

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# X_train shape: (431, 132)
# y_train shape: (431,)

# %%
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_test shape: (108, 132)
# y_test shape: (108,)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

model = DecisionTreeRegressor(random_state=22)

model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=22)

# %%
y_train_hat = model.predict(X_train)
y_test_hat = model.predict(X_test)

# %%
# 모델 성능 평가 결과 training set에 대해서는 성능이 우수하나 test set에 대해서는 성능이 떨어지는 overfitting의 양상을 보임
from sklearn.metrics import mean_squared_error
import numpy as np

rmse_train = np.sqrt(mean_squared_error(y_train, y_train_hat))
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_hat))

print("RMSE on training set:", rmse_train)
print("RMSE on test set:", rmse_test)
# Out:
# RMSE on training set: 3.0758224916771577e-18
# RMSE on test set: 27.33947856055347

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_test_hat)
print("R² Score:", r2)
# Out:
# R² Score: -0.10775573344679423

# %%
#GridSearchCV 를 통한 적절한 hyperparameter 찾기
from sklearn.model_selection import GridSearchCV

# 모델 생성
model = DecisionTreeRegressor(random_state=22)

# GridSearchCV 수행을 위한 파라미터 후보군 정의
param_grid = {
    'max_depth': [2, 3, 4, 5, 10, 20],
    'min_samples_split': [2, 3, 4, 5, 12, 13, 14, 15],
    'min_samples_leaf': [1, 2, 3, 4, 5],
}

# GridSearchCV 수행
grid_search = GridSearchCV(model, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train, y_train)

# 최적의 하이퍼파라미터와 점수 출력
print("Best hyperparameters: ", grid_search.best_params_)
print("Best score: ", -grid_search.best_score_)
# Out:
# Best hyperparameters:  {'max_depth': 2, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Best score:  3817.6699081572815

# %%
model = DecisionTreeRegressor(max_depth=2, min_samples_leaf=2, min_samples_split=2, random_state=22)
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=2, min_samples_leaf=2, random_state=22)

# %%
y_train_hat = model.predict(X_train)
y_test_hat = model.predict(X_test)

# %%
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_hat))
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_hat))

print("RMSE on training set:", rmse_train)
print("RMSE on test set:", rmse_test)
# Out:
# RMSE on training set: 43.690235525782256
# RMSE on test set: 69.39509394956816

# %%
r2 = r2_score(y_test, y_test_hat)
print("R² Score:", r2)
# Out:
# R² Score: -6.137088604388876

# %%
#tree 시각화
import graphviz 
from sklearn.tree import export_graphviz

dot_data = export_graphviz(model, out_file=None, 
                           feature_names=X_train.columns,  
                           filled=True, rounded=True,  
                           special_characters=True)  
graph = graphviz.Source(dot_data)  
graph.render("tree", format='png')  
graph
