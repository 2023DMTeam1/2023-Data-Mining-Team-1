# %%
import pandas as pd
df = pd.read_csv("/content/sample_data/4_허건호02.csv",encoding='UTF8')

# %%
df
# Out:
#                   화재발생일시  화재발생_연  화재발생_월  화재발생_일  주말여부 화재발생시간대 시군구명  읍면동명  \
# 0    2011-01-22 23:35:00    2011       1      22     1   21~24  강릉시   죽헌동
# 1    2011-01-31 18:13:00    2011       1      31     0   18~21  양양군   현남면
# 2    2011-02-11 17:50:00    2011       2      11     0   15~18  홍천군   내촌면
# 3    2011-02-12 06:18:00    2011       2      12     1     3~6  원주시   귀래면
# 4    2011-02-26 16:42:00    2011       2      26     1   15~18  원주시   태장동
# ..                   ...     ...     ...     ...   ...     ...  ...   ...
# 534  2021-05-09 13:43:01    2021       5       9     1   12~15  철원군   철원읍
# 535  2021-05-09 17:44:49    2021       5       9     1   15~18  철원군   철원읍
# 536  2021-05-13 15:37:05    2021       5      13     0   15~18  태백시  하사미동
# 537  2021-06-07 15:11:39    2021       6       7     0   15~18  강릉시  주문진읍
# 538  2021-06-08 14:52:46    2021       6       8     0   12~15  홍천군   내촌면
#
#     발화지점    날씨  ...  출동소요시간  현장소방서거리  현장안전센터거리 현장소방지역대거리 전체인력수합계  화재진압시간  \
# 0    산정상    맑음  ...    1700        9         9       0.0      37    1800
# 1    산아래    맑음  ...    1615       43        13       0.0    1872  155952
# 2    산중턱  구름많음  ...    2240       37        37       7.0     171   20500
# 3    산중턱  구름많음  ...    2019       20        20       8.0      94   35009
# 4    산정상    맑음  ...     508        8         2       0.0      46    3825
# ..   ...   ...  ...     ...      ...       ...       ...     ...     ...
# 534  산중턱    맑음  ...     801       16         7       0.0      60    2915
# 535  산정상    맑음  ...     347       12         1       0.0      67    4529
# 536  산중턱    맑음  ...    2121       20        17       0.0     144   43459
# 537  산중턱    맑음  ...    1344       21         6       0.0      50   12539
# 538  산정상    맑음  ...     935       26         0       5.0      48   12515
#
#     동원장비수 인명피해수  재산피해금액   피해면적
# 0       8     0       0   0.30
# 1      71     0  184330  30.00
# 2       9     0    4864   0.30
# 3       9     0      50   0.30
# 4       8     0     440   0.03
# ..    ...   ...     ...    ...
# 534    12     0       0   0.03
# 535    13     0       0   0.01
# 536    18     0       0   1.20
# 537    11     0     223   0.01
# 538     6     0       0   0.04
#
# [539 rows x 28 columns]

# %%
df.shape
# Out:
# (539, 28)

# %%
df.keys
# Out:
# <bound method NDFrame.keys of                   화재발생일시  화재발생_연  화재발생_월  화재발생_일  주말여부 화재발생시간대 시군구명  읍면동명  \
# 0    2011-01-22 23:35:00    2011       1      22     1   21~24  강릉시   죽헌동
# 1    2011-01-31 18:13:00    2011       1      31     0   18~21  양양군   현남면
# 2    2011-02-11 17:50:00    2011       2      11     0   15~18  홍천군   내촌면
# 3    2011-02-12 06:18:00    2011       2      12     1     3~6  원주시   귀래면
# 4    2011-02-26 16:42:00    2011       2      26     1   15~18  원주시   태장동
# ..                   ...     ...     ...     ...   ...     ...  ...   ...
# 534  2021-05-09 13:43:01    2021       5       9     1   12~15  철원군   철원읍
# 535  2021-05-09 17:44:49    2021       5       9     1   15~18  철원군   철원읍
# 536  2021-05-13 15:37:05    2021       5      13     0   15~18  태백시  하사미동
# 537  2021-06-07 15:11:39    2021       6       7     0   15~18  강릉시  주문진읍
# 538  2021-06-08 14:52:46    2021       6       8     0   12~15  홍천군   내촌면
#
#     발화지점    날씨  ...  출동소요시간  현장소방서거리  현장안전센터거리 현장소방지역대거리 전체인력수합계  화재진압시간  \
# 0    산정상    맑음  ...    1700        9         9       0.0      37    1800
# 1    산아래    맑음  ...    1615       43        13       0.0    1872  155952
# 2    산중턱  구름많음  ...    2240       37        37       7.0     171   20500
# 3    산중턱  구름많음  ...    2019       20        20       8.0      94   35009
# 4    산정상    맑음  ...     508        8         2       0.0      46    3825
# ..   ...   ...  ...     ...      ...       ...       ...     ...     ...
# 534  산중턱    맑음  ...     801       16         7       0.0      60    2915
# 535  산정상    맑음  ...     347       12         1       0.0      67    4529
# 536  산중턱    맑음  ...    2121       20        17       0.0     144   43459
# 537  산중턱    맑음  ...    1344       21         6       0.0      50   12539
# 538  산정상    맑음  ...     935       26         0       5.0      48   12515
#
#     동원장비수 인명피해수  재산피해금액   피해면적
# 0       8     0       0   0.30
# 1      71     0  184330  30.00
# 2       9     0    4864   0.30
# 3       9     0      50   0.30
# 4       8     0     440   0.03
# ..    ...   ...     ...    ...
# 534    12     0       0   0.03
# 535    13     0       0   0.01
# 536    18     0       0   1.20
# 537    11     0     223   0.01
# 538     6     0       0   0.04
#
# [539 rows x 28 columns]>

# %%
df['피해면적'].shape
# Out:
# (539,)

# %%
df['화재발생_월'].shape
# Out:
# (539,)

# %%
df['주말여부'].shape
# Out:
# (539,)

# %%
df['화재발생시간대'].shape
# Out:
# (539,)

# %%
df['시군구명'].shape
# Out:
# (539,)

# %%
df['발화지점'].shape
# Out:
# (539,)

# %%
df['날씨'].shape
# Out:
# (539,)

# %%
df['온도'].shape
# Out:
# (539,)

# %%
df['습도'].shape
# Out:
# (539,)

# %%
df['발화원인종합'].shape
# Out:
# (539,)

# %%
data = df.drop(['화재발생일시','화재발생_연','화재발생_일','읍면동명','시간단위풍속','특보내용','소방서명','서센터명','소방지역대명','출동소요시간','현장소방서거리','현장안전센터거리','현장소방지역대거리','전체인력수합계','화재진압시간','동원장비수','인명피해수','재산피해금액'],axis=1)

# %%
data
#분석에 필요한 변수만 남김
# Out:
#      화재발생_월  주말여부 화재발생시간대 시군구명 발화지점    날씨  온도  습도       발화원인종합   피해면적
# 0         1     1   21~24  강릉시  산정상    맑음  -1  30    방화 및 방화의심   0.30
# 1         1     0   18~21  양양군  산아래    맑음   1  10      인간의 부주의  30.00
# 2         2     0   15~18  홍천군  산중턱  구름많음  -2  29      인간의 부주의   0.30
# 3         2     1     3~6  원주시  산중턱  구름많음  -6  44      인간의 부주의   0.30
# 4         2     1   15~18  원주시  산정상    맑음  14  23      인간의 부주의   0.03
# ..      ...   ...     ...  ...  ...   ...  ..  ..          ...    ...
# 534       5     1   12~15  철원군  산중턱    맑음  19  26      인간의 부주의   0.03
# 535       5     1   15~18  철원군  산정상    맑음  18  22      인간의 부주의   0.01
# 536       5     0   15~18  태백시  산중턱    맑음  23  43  기계/전기/화학 요인   1.20
# 537       6     0   15~18  강릉시  산중턱    맑음  25  62      인간의 부주의   0.01
# 538       6     0   12~15  홍천군  산정상    맑음  18  78       자연적 요인   0.04
#
# [539 rows x 10 columns]

# %%
#Feature 와 target 나누기
features = data[data.columns[:-1]]
target = data[data.columns[-1]]

# %%
# 문자열 데이터를 숫자형 데이터로 변환
features = pd.get_dummies(data = features, columns = ['화재발생시간대'], prefix = '화재발생시간대')
features = pd.get_dummies(data = features, columns = ['시군구명'], prefix = '시군구명')
features = pd.get_dummies(data = features, columns = ['발화지점'], prefix = '발화지점')
features = pd.get_dummies(data = features, columns = ['날씨'], prefix = '날씨')
features = pd.get_dummies(data = features, columns = ['발화원인종합'], prefix = '발화원인종합')

# %%
#Data split: Train,test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    features, target, test_size=0.1,random_state = 22
)

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# X_train shape: (485, 46)
# y_train shape: (485,)

# %%
X_train
# Out:
#      화재발생_월  주말여부  온도  습도  화재발생시간대_0~3  화재발생시간대_12~15  화재발생시간대_15~18  \
# 172       3     0   5  41            0              0              0
# 379      11     0   4  26            0              0              0
# 329       4     0  20  11            0              0              1
# 28       11     0  14  63            0              0              1
# 137       6     0  23  72            0              0              1
# ..      ...   ...  ..  ..          ...            ...            ...
# 491       4     0  23  33            1              0              0
# 502      10     0  18  51            1              0              0
# 358       5     1  20  23            0              0              0
# 356       5     1  22  12            0              0              1
# 132       5     0  23  30            0              0              0
#
#      화재발생시간대_18~21  화재발생시간대_21~24  화재발생시간대_3~6  ...  날씨_구름조금  날씨_맑음  날씨_비  \
# 172              1              0            0  ...        0      1     0
# 379              0              0            0  ...        0      1     0
# 329              0              0            0  ...        0      1     0
# 28               0              0            0  ...        1      0     0
# 137              0              0            0  ...        0      0     1
# ..             ...            ...          ...  ...      ...    ...   ...
# 491              0              0            0  ...        0      1     0
# 502              0              0            0  ...        0      1     0
# 358              1              0            0  ...        0      1     0
# 356              0              0            0  ...        0      1     0
# 132              1              0            0  ...        0      1     0
#
#      날씨_소나기  날씨_흐림  발화원인종합_기계/전기/화학 요인  발화원인종합_미상  발화원인종합_방화 및 방화의심  \
# 172       0      0                   0          0                 0
# 379       0      0                   0          0                 0
# 329       0      0                   0          0                 0
# 28        0      0                   0          0                 0
# 137       0      0                   0          0                 0
# ..      ...    ...                 ...        ...               ...
# 491       0      0                   0          1                 0
# 502       0      0                   0          1                 0
# 358       0      0                   0          0                 0
# 356       0      0                   0          0                 0
# 132       0      0                   0          0                 0
#
#      발화원인종합_인간의 부주의  발화원인종합_자연적 요인
# 172               1              0
# 379               1              0
# 329               1              0
# 28                1              0
# 137               1              0
# ..              ...            ...
# 491               0              0
# 502               0              0
# 358               1              0
# 356               1              0
# 132               1              0
#
# [485 rows x 46 columns]

# %%
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X
# 512       0      0                   0          0                 0
#
#      발화원인종합_인간의 부주의  발화원인종합_자연적 요인
# 311               1              0
# 162               1              0
# 325               1              0
# 134               1              0
# 213               0              0
# 432               1              0
# 353               1              0
# 360               1              0
# 127               1              0
# 22                1              0
# 123               1              0
# 46                0              0
# 303               1              0
# 89                0              0
# 437               1              0
# 158               1              0
# 146               1              0
# 188               1              0
# 299               1              0
# 157               1              0
# 276               1              0
# 528               1              0
# 163               1              0
# 221               1              0
# 30                1              0
# 255               1              0
# 480               1              0
# 2                 1              0
# 166               1              0
# 361               1              0
# 369               1              0
# 535               1              0
# 492               1              0
# 254               1              0
# 203               1              0
# 300               1              0
# 111               0              0
# 324               1              0
# 206               1              0
# 470               1              0
# 59                1              0
# 488               0              0
# 434               1              0
# 518               1              0
# 531               1              0
# 189               0              0
# 263               1              0
# 215               1              0
# 101               1              0
# 482               1              0
# 428               1              0
# 216               1              0
# 495               1              0
# 512               1              0
#
# [54 rows x 46 columns]

# %%
#Data split: Train,Validation,
X_train, X_val, y_train, y_val = train_test_split(X_train,y_train,test_size=0.3,random_state=22)

# %%
print("X_train shape:", X_train.shape)
print("X_val shape:", X_val.shape)
print("y_train shape:", y_train.shape)
print("y_val shape:", y_val.shape)
# Out:
# X_train shape: (339, 46)
# X_val shape: (146, 46)
# y_train shape: (339,)
# y_val shape: (146,)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

model = DecisionTreeRegressor(random_state=22)

model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=22)

# %%
y_train_hat = model.predict(X_train)
y_test_hat = model.predict(X_test)

# %%
# 모델 성능 평가 결과 training set에 대해서는 성능이 우수하나 test set에 대해서는  성능이 떨어지는 overfitting의 양상을 보임
from sklearn.metrics import mean_squared_error
import numpy as np

rmse_train = np.sqrt(mean_squared_error(y_train, y_train_hat))
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_hat))

print("RMSE on training set:", rmse_train)
print("RMSE on test set:", rmse_test)
# Out:
# RMSE on training set: 3.263781149452629e-18
# RMSE on test set: 175.39495588000287

# %%
#GridSearchCV 를 통한 적절한 hyperparameter 찾기
from sklearn.model_selection import GridSearchCV

# 모델 생성
model = DecisionTreeRegressor(random_state=22)

# GridSearchCV 수행을 위한 파라미터 후보군 정의
param_grid = {
    'max_depth': [2, 3, 4, 5, 10, 20],
    'min_samples_split': [2, 3, 4, 5, 12, 13, 14, 15],
    'min_samples_leaf': [1, 2, 3, 4, 5],
}

# GridSearchCV 수행
grid_search = GridSearchCV(model, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_val, y_val)

# 최적의 하이퍼파라미터와 점수 출력
print("Best hyperparameters: ", grid_search.best_params_)
print("Best score: ", -grid_search.best_score_)
# Out:
# Best hyperparameters:  {'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Best score:  25.67293898952759

# %%
model = DecisionTreeRegressor(max_depth=2, min_samples_leaf=1, min_samples_split=10, random_state=22)
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=2, min_samples_split=10, random_state=22)

# %%
y_train_hat = model.predict(X_train)
y_test_hat = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

rmse_train = np.sqrt(mean_squared_error(y_train, y_train_hat))
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_hat))

print("RMSE on training set:", rmse_train)
print("RMSE on test set:", rmse_test)
# Out:
# RMSE on training set: 59.02501072338025
# RMSE on test set: 68.10244655066933

# %%
#tree 시각화
import graphviz 
from sklearn.tree import export_graphviz

dot_data = export_graphviz(model, out_file=None, 
                           feature_names=X_train.columns,  
                           filled=True, rounded=True,  
                           special_characters=True)  
graph = graphviz.Source(dot_data)  
graph.render("tree", format='png')  
graph
